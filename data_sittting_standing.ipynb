# %% [markdown]
# <a href="https://colab.research.google.com/github/sisifo3/P_T_4/blob/main/data_sittting_standing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/mishra-ankit/ddg-image-downloader

# %%
# !npm install -g ddg-bulk-image-downloader
# Out:
# /tools/node/bin/ddg-download -> /tools/node/lib/node_modules/ddg-bulk-image-downloader/bin/run
# + ddg-bulk-image-downloader@0.1.11
# added 146 packages from 78 contributors in 13.398s

# %%
# !ddg-download "sitting people" -l 1270 # Downloads first 500 images from Duck Duck go to current folder
# Out:
# Initializing download...
# Initializing download... ⣾
# Fetching https://duckduckgo.com/i.js?o=json&l=wt-wt&f=&q=sitting%20people&vqd=3-323899614327202463453794894808906686024-138715393788132230994278379252081294656
# Initializing download... ⣽
# Initializing download... ⣻
# Initializing download... ⢿
# Initializing download... ⡿
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=sitting%20people&o=json&p=1&s=100&u=bing&l=wt-wt&vqd=3-323899614327202463453794894808906686024-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=sitting%20people&o=json&p=1&s=200&u=bing&l=wt-wt&vqd=3-323899614327202463453794894808906686024-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=sitting%20people&o=json&p=1&s=300&u=bing&l=wt-wt&vqd=3-323899614327202463453794894808906686024-138715393788132230994278379252081294656
# ...
# Status 200
# ...

# %%
#$ ddg-download -q "sitting people" -l 60 -o out

# %%
for i in range(70) :
  i = i + 1201
  num = str(i)
  print('!cp "/content/sitting people_"' + num + '.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"')
  print('%rm -rf "/content/sitting people_' + num + '.png"')
# Out:
# !cp "/content/sitting people_"1201.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1201.png"
# !cp "/content/sitting people_"1202.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1202.png"
# !cp "/content/sitting people_"1203.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1203.png"
# !cp "/content/sitting people_"1204.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1204.png"
# !cp "/content/sitting people_"1205.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1205.png"
# ...

# %%
# !cp "/content/sitting people_"1201.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1201.png"
# !cp "/content/sitting people_"1202.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1202.png"
# !cp "/content/sitting people_"1203.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1203.png"
# !cp "/content/sitting people_"1204.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1204.png"
# !cp "/content/sitting people_"1205.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1205.png"
# !cp "/content/sitting people_"1206.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1206.png"
# !cp "/content/sitting people_"1207.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1207.png"
# !cp "/content/sitting people_"1208.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1208.png"
# !cp "/content/sitting people_"1209.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1209.png"
# !cp "/content/sitting people_"1210.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1210.png"
# !cp "/content/sitting people_"1211.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1211.png"
# !cp "/content/sitting people_"1212.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1212.png"
# !cp "/content/sitting people_"1213.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1213.png"
# !cp "/content/sitting people_"1214.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1214.png"
# !cp "/content/sitting people_"1215.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1215.png"
# !cp "/content/sitting people_"1216.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1216.png"
# !cp "/content/sitting people_"1217.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1217.png"
# !cp "/content/sitting people_"1218.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1218.png"
# !cp "/content/sitting people_"1219.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1219.png"
# !cp "/content/sitting people_"1220.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1220.png"
# !cp "/content/sitting people_"1221.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1221.png"
# !cp "/content/sitting people_"1222.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1222.png"
# !cp "/content/sitting people_"1223.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1223.png"
# !cp "/content/sitting people_"1224.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1224.png"
# !cp "/content/sitting people_"1225.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1225.png"
# !cp "/content/sitting people_"1226.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1226.png"
# !cp "/content/sitting people_"1227.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1227.png"
# !cp "/content/sitting people_"1228.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1228.png"
# !cp "/content/sitting people_"1229.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1229.png"
# !cp "/content/sitting people_"1230.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1230.png"
# !cp "/content/sitting people_"1231.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1231.png"
# !cp "/content/sitting people_"1232.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1232.png"
# !cp "/content/sitting people_"1233.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1233.png"
# !cp "/content/sitting people_"1234.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1234.png"
# !cp "/content/sitting people_"1235.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1235.png"
# !cp "/content/sitting people_"1236.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1236.png"
# !cp "/content/sitting people_"1237.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1237.png"
# !cp "/content/sitting people_"1238.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1238.png"
# !cp "/content/sitting people_"1239.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1239.png"
# !cp "/content/sitting people_"1240.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1240.png"
# !cp "/content/sitting people_"1241.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1241.png"
# !cp "/content/sitting people_"1242.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1242.png"
# !cp "/content/sitting people_"1243.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1243.png"
# !cp "/content/sitting people_"1244.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1244.png"
# !cp "/content/sitting people_"1245.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1245.png"
# !cp "/content/sitting people_"1246.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1246.png"
# !cp "/content/sitting people_"1247.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1247.png"
# !cp "/content/sitting people_"1248.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1248.png"
# !cp "/content/sitting people_"1249.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1249.png"
# !cp "/content/sitting people_"1250.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1250.png"
# !cp "/content/sitting people_"1251.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1251.png"
# !cp "/content/sitting people_"1252.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1252.png"
# !cp "/content/sitting people_"1253.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1253.png"
# !cp "/content/sitting people_"1254.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1254.png"
# !cp "/content/sitting people_"1255.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1255.png"
# !cp "/content/sitting people_"1256.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1256.png"
# !cp "/content/sitting people_"1257.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1257.png"
# !cp "/content/sitting people_"1258.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1258.png"
# !cp "/content/sitting people_"1259.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1259.png"
# !cp "/content/sitting people_"1260.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1260.png"
# !cp "/content/sitting people_"1261.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1261.png"
# !cp "/content/sitting people_"1262.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1262.png"
# !cp "/content/sitting people_"1263.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1263.png"
# !cp "/content/sitting people_"1264.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1264.png"
# !cp "/content/sitting people_"1265.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1265.png"
# !cp "/content/sitting people_"1266.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1266.png"
# !cp "/content/sitting people_"1267.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1267.png"
# !cp "/content/sitting people_"1268.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1268.png"
# !cp "/content/sitting people_"1269.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1269.png"
# !cp "/content/sitting people_"1270.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/sitting_people/"
# %rm -rf "/content/sitting people_1270.png"
# Out:
# cp: cannot stat '/content/sitting people_1201.png': No such file or directory
# cp: cannot stat '/content/sitting people_1205.png': No such file or directory
# cp: cannot stat '/content/sitting people_1207.png': No such file or directory
# cp: cannot stat '/content/sitting people_1208.png': No such file or directory
# cp: cannot stat '/content/sitting people_1210.png': No such file or directory
# cp: cannot stat '/content/sitting people_1211.png': No such file or directory
# cp: cannot stat '/content/sitting people_1212.png': No such file or directory
# cp: cannot stat '/content/sitting people_1213.png': No such file or directory
# cp: cannot stat '/content/sitting people_1214.png': No such file or directory
# cp: cannot stat '/content/sitting people_1215.png': No such file or directory
# cp: cannot stat '/content/sitting people_1216.png': No such file or directory
# cp: cannot stat '/content/sitting people_1218.png': No such file or directory
# ...

# %%
# !ddg-download "standing people" -l 1270 # Downloads first 500 images from Duck Duck go to current folder
# Out:
# Initializing download...
# Initializing download... ⣾
# Fetching https://duckduckgo.com/i.js?o=json&l=wt-wt&f=&q=standing%20people&vqd=3-123931794974776230679999855642192087287-138715393788132230994278379252081294656
# Initializing download... ⣽
# Initializing download... ⣻
# Initializing download... ⢿
# Initializing download... ⡿
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=standing%20people&o=json&p=1&s=100&u=bing&l=wt-wt&vqd=3-123931794974776230679999855642192087287-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=standing%20people&o=json&p=1&s=200&u=bing&l=wt-wt&vqd=3-123931794974776230679999855642192087287-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# ...
# ...
# Fetching https://duckduckgo.com/i.js?q=standing%20people&o=json&p=1&s=300&u=bing&l=wt-wt&vqd=3-123931794974776230679999855642192087287-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# Done! 1270 images saved

# %%
for i in range(70) :
  i = i + 1201
  num = str(i)
  print('!cp "/content/standing people_"' + num + '.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"')
  print('%rm -rf "/content/standing people_' + num + '.png"')
# Out:
# !cp "/content/standing people_"1201.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1201.png"
# !cp "/content/standing people_"1202.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1202.png"
# !cp "/content/standing people_"1203.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1203.png"
# !cp "/content/standing people_"1204.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1204.png"
# !cp "/content/standing people_"1205.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1205.png"
# ...

# %%
# !cp "/content/standing people_"1242.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1242.png"
# !cp "/content/standing people_"1243.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1243.png"
# !cp "/content/standing people_"1244.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1244.png"
# !cp "/content/standing people_"1245.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1245.png"
# !cp "/content/standing people_"1246.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1246.png"
# !cp "/content/standing people_"1247.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1247.png"
# !cp "/content/standing people_"1248.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1248.png"
# !cp "/content/standing people_"1249.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1249.png"
# !cp "/content/standing people_"1250.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1250.png"
# !cp "/content/standing people_"1251.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1251.png"
# !cp "/content/standing people_"1252.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1252.png"
# !cp "/content/standing people_"1253.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1253.png"
# !cp "/content/standing people_"1254.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1254.png"
# !cp "/content/standing people_"1255.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1255.png"
# !cp "/content/standing people_"1256.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1256.png"
# !cp "/content/standing people_"1257.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1257.png"
# !cp "/content/standing people_"1258.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1258.png"
# !cp "/content/standing people_"1259.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1259.png"
# !cp "/content/standing people_"1260.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1260.png"
# !cp "/content/standing people_"1261.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1261.png"
# !cp "/content/standing people_"1262.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1262.png"
# !cp "/content/standing people_"1263.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1263.png"
# !cp "/content/standing people_"1264.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1264.png"
# !cp "/content/standing people_"1265.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1265.png"
# !cp "/content/standing people_"1266.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1266.png"
# !cp "/content/standing people_"1267.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1267.png"
# !cp "/content/standing people_"1268.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1268.png"
# !cp "/content/standing people_"1269.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1269.png"
# !cp "/content/standing people_"1270.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1270.png"
# Out:
# cp: cannot stat '/content/standing people_1242.png': No such file or directory
# cp: cannot stat '/content/standing people_1243.png': No such file or directory
# cp: cannot stat '/content/standing people_1244.png': No such file or directory
# cp: cannot stat '/content/standing people_1245.png': No such file or directory
# cp: cannot stat '/content/standing people_1246.png': No such file or directory
# cp: cannot stat '/content/standing people_1247.png': No such file or directory
# cp: cannot stat '/content/standing people_1248.png': No such file or directory
# cp: cannot stat '/content/standing people_1249.png': No such file or directory
# cp: cannot stat '/content/standing people_1250.png': No such file or directory
# cp: cannot stat '/content/standing people_1251.png': No such file or directory
# cp: cannot stat '/content/standing people_1252.png': No such file or directory
# cp: cannot stat '/content/standing people_1253.png': No such file or directory
# ...
