# %% [markdown]
# <a href="https://colab.research.google.com/github/sisifo3/P_T_4/blob/main/data_sittting_standing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/mishra-ankit/ddg-image-downloader

# %%
# !npm install -g ddg-bulk-image-downloader
# Out:
# /tools/node/bin/ddg-download -> /tools/node/lib/node_modules/ddg-bulk-image-downloader/bin/run
# + ddg-bulk-image-downloader@0.1.11
# added 128 packages from 73 contributors in 12.195s

# %%
# !ddg-download "standing people in a office" -l 1500 # Downloads first 500 images from Duck Duck go to current folder
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# ...
# ...
# ^C

# %%
# !ddg-download "sitting people in a office" -l 2000 # Downloads first 500 images from Duck Duck go to current folder
# Out:
# Streaming output truncated to the last 5000 lines.
# Initializing download... ⣻
# Initializing download... ⢿
# Initializing download... ⡿
# Initializing download... ⣟
# Initializing download... ⣯
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=sitting%20people%20in%20a%20office&o=json&p=1&s=100&u=bing&l=wt-wt&vqd=3-168507258159367071297918393780471584565-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=sitting%20people%20in%20a%20office&o=json&p=1&s=200&u=bing&l=wt-wt&vqd=3-168507258159367071297918393780471584565-138715393788132230994278379252081294656
# ...
# Status 200
# ...
# Fetching https://duckduckgo.com/i.js?q=sitting%20people%20in%20a%20office&o=json&p=1&s=300&u=bing&l=wt-wt&vqd=3-168507258159367071297918393780471584565-138715393788132230994278379252081294656
# ...
# Status 200
# ...

# %%
#$ ddg-download -q "sitting people" -l 60 -o out

# %%
#/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/val/sitting_people
#for i in range(854) :
#  i = i + 12000
#  num = str(i)
#  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/sitting_people/sitting people_"' + num + '.jpg -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/val/sitting_people/"')
#  print('%rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/sitting_people/sitting people_' + num + '.jpg"')

# %%
for i in range(1000) :
  i = i + 1000
  num = str(i)
  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/sitting people in a office_' + num + '.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"')
  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/sitting people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"')

  #print('!cp "/content/sitting people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/Tsitting_people/"')
# Out:
# !cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/sitting people in a office_1000.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"
# !cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/sitting people in a office_1000.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"
# !cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/sitting people in a office_1001.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"
# !cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/sitting people in a office_1001.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"
# ...

# %%
#/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/sitting_people
#/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people
#/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_0.png

for i in range(1000) :
  i = i + 2000
  num = str(i)
  #print('!cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_' + num + '.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/sitting_people_H/"')
  print('%rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_' + num + '.jpg"')
  #print('!cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/sitting_people_H/"')
  print('%rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_' + num + '.png"')
# Out:
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2000.jpg"
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2000.png"
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2001.jpg"
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2001.png"
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2002.jpg"
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2002.png"
# %rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/sitting people_2003.jpg"
# ...

# %%
#/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/sitting_people
#/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people
for i in range(1000) :
  i = i + 9000
  num = str(i)
  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_' + num + '.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_F/"')
  #print('%rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_' + num + '.jpg"')
  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_F/"')
  #print('%rm -rf "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_' + num + '.png"')
# Out:
# !cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_9000.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_F/"
# !cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_9000.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_F/"
# !cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_9001.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_F/"
# !cp "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/standing_people/standing people_9001.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_F/"
# ...

# %%
#/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/sitting_people
#/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people
for i in range(1000) :
  i = i + 1000
  num = str(i)
  print('!cp "/content/sitting people in a office_' + num + '.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/Tsitting_people/"')
  print('%rm -rf "/content/sitting people in a office_' + num + '.jpg"')
  print('!cp "/content/sitting people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/Tsitting_people/"')
  print('%rm -rf "/content/sitting people in a office_' + num + '.png"')
  
  #print('!cp "/content/sitting people_"' + num + '.jpg -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/"')
  #print('%rm -rf "/content/sitting people_' + num + '.jpg"')
  #print('!cp "/content/sitting people_"' + num + '.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/train/sitting_people/"')
  #print('%rm -rf "/content/sitting people_' + num + '.png"')

# %%
for i in range(1000) :
  i = i + 1000
  num = str(i)
  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people_2/standing people in a office_' + num + '.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"')
  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people_2/standing people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"')

#  print('!cp "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people_2/standing people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/sitting_people/"')

  #print('!cp "/content/sitting people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/Tsitting_people/"')

# %%
#!ddg-download "standing people in a office" -l 2000 #Downloads first 500 images from Duck Duck go to current folder
# !ddg-download "standing people in a office" -l 1500 # Downloads first 500 images from Duck Duck go to current folder
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# ...
# ...

# %%
#/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/standing_people
#/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people
for i in range(1000) :
  i = i + 0
  num = str(i)
  print('!cp "/content/standing people in a office_' + num + '.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"')
  print('%rm -rf "/content/standing people in a office_' + num + '.jpg"')
  print('!cp "/content/standing people in a office_' + num + '.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"')
  print('%rm -rf "/content/standing people in a office_' + num + '.png"')


#for i in range(70) :
#  i = i + 1201
#  num = str(i)
#  print('!cp "/content/standing people_"' + num + '.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/standing_people/"')
#  print('%rm -rf "/content/standing people_' + num + '.png"')
# Out:
# !cp "/content/standing people in a office_0.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"
# %rm -rf "/content/standing people in a office_0.jpg"
# !cp "/content/standing people in a office_0.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"
# %rm -rf "/content/standing people in a office_0.png"
# !cp "/content/standing people in a office_1.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"
# %rm -rf "/content/standing people in a office_1.jpg"
# !cp "/content/standing people in a office_1.png" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"
# %rm -rf "/content/standing people in a office_1.png"
# !cp "/content/standing people in a office_2.jpg" -r "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train/standing_people/"
# ...

# %%
for i in range(70) :
  i = i + 1201
  num = str(i)
  print('!cp "/content/standing people_"' + num + '.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"')
  print('%rm -rf "/content/standing people_' + num + '.png"')
# Out:
# !cp "/content/standing people_"1201.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1201.png"
# !cp "/content/standing people_"1202.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1202.png"
# !cp "/content/standing people_"1203.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1203.png"
# !cp "/content/standing people_"1204.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1204.png"
# !cp "/content/standing people_"1205.png -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset/test/standing_people/"
# %rm -rf "/content/standing people_1205.png"
# ...

# %%
num = 1047
# !cp "/content/standing people_14280.png" -r "/content/drive/MyDrive/video_work_environment/sitting_stading_dataset_v2/test/standing_people/"
# Out:
# cp: cannot stat '/content/standing people_14280.png': No such file or directory

# %%
import os
j=0
path = "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/sitting_people_3/"
files = os.listdir(path)
#print(f"Before Renaming: {files}")
for i in range(len(files)):
  j = j +1
  num = str(j) 
  #print(files[i])
  os.rename(path+files[i], f"{path}img_{num}.png")
#print(f"After Renaming: {os.listdir(path)}")
# Out:
# After Renaming: ['img_2.png', 'img_3.png', 'img_4.png', 'img_5.png', 'img_6.png', 'img_7.png', 'img_8.png', 'img_9.png', 'img_10.png', 'img_11.png', 'img_12.png', 'img_13.png', 'img_14.png', 'img_15.png', 'img_16.png', 'img_17.png', 'img_18.png', 'img_19.png', 'img_20.png', 'img_21.png', 'img_22.png', 'img_23.png', 'img_24.png', 'img_25.png', 'img_26.png', 'img_27.png', 'img_28.png', 'img_29.png', 'img_30.png', 'img_31.png', 'img_32.png', 'img_33.png', 'img_34.png', 'img_35.png', 'img_36.png', 'img_37.png', 'img_38.png', 'img_39.png', 'img_40.png', 'img_41.png', 'img_42.png', 'img_43.png', 'img_44.png', 'img_45.png', 'img_46.png', 'img_47.png', 'img_48.png', 'img_49.png', 'img_50.png', 'img_51.png', 'img_52.png', 'img_53.png', 'img_54.png', 'img_55.png', 'img_56.png', 'img_57.png', 'img_58.png', 'img_59.png', 'img_60.png', 'img_61.png', 'img_62.png', 'img_63.png', 'img_64.png', 'img_65.png', 'img_66.png', 'img_67.png', 'img_68.png', 'img_69.png', 'img_70.png', 'img_71.png', 'img_72.p
# ...

# %%
import os
j=0
path = "/content/drive/MyDrive/video_work_environment/sitting_standing_dataset_v3/train_parts/standing_people_3/"
files = os.listdir(path)
#print(f"Before Renaming: {files}")
for i in range(len(files)):
  j = j +1
  num = str(j) 
  #print(files[i])
  os.rename(path+files[i], f"{path}img_{num}.png")
